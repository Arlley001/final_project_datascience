# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook we summarize some of the most commonly used tools, languages, and libraries in Data Science.

# %% [markdown]
# Some popular languages that Data Scientists use are:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Java
# 5. Julia

# %% [markdown]
# Some of the commonly used Data Science libraries are:
#
# 1. Pandas
# 2. NumPy
# 3. Matplotlib
# 4. Scikit-learn
# 5. TensorFlow

# %% [markdown]
# | Data Science Tool      | Category          |
# |------------------------|-------------------|
# | Jupyter Notebook       | Notebook          |
# | RStudio                | IDE               |
# | Visual Studio Code     | IDE               |
# | Apache Spark           | Big Data / Engine |
# | TensorFlow             | Deep Learning     |

# %% [markdown]
# Below are a few examples of evaluating arithmetic expressions in Python.

# %%
# This expression multiplies two numbers and then adds another number
result = (3 * 4) + 5
result
# Out:
# 17

# %%
# This code converts minutes to hours
minutes = 200
hours = minutes / 60
hours
# Out:
# 3.3333333333333335

# %%
# Objectives of this notebook
objectives = [
    "List popular languages for Data Science",
    "Identify commonly used Data Science libraries",
    "Create a table of Data Science tools",
    "Practice arithmetic expressions in Python",
    "Get familiar with Jupyter notebooks and GitHub"
]

for obj in objectives:
    print("-", obj)
# Out:
# - List popular languages for Data Science
# - Identify commonly used Data Science libraries
# - Create a table of Data Science tools
# - Practice arithmetic expressions in Python
# - Get familiar with Jupyter notebooks and GitHub

# %% [markdown]
# ## Author
#
# ARLLEY OBESSO
